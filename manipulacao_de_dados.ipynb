# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/2004-2021.tsv', sep='\t')
df

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# adicionando coluna com valor default
df['Coluna sem nocao'] = 'DEFAULT'
df

# adicionando coluna a partir de lista
df['Coluna a partir de lista'] = range(df.shape[0])
df

# adicionando coluna com base em operacao em outra coluna
df['preco medio revenda (dolar)'] = df['PREÇO MÉDIO REVENDA'] * 6
df

# %%
# transformando indice em lista de str e iterando sobre ela

pesquisa_de_satisfacao = pd.DataFrame({

    'Bom':[50,21,100],
    'Ruim': [131,2,30],
    'pessimo':[30,20,1]
},index=['XboxOne','PS4','Nintendo Switch'])

pesquisa_de_satisfacao.index

lista = list(pesquisa_de_satisfacao.index)

for console in lista:
    print(console)
# Out:
# XboxOne
# PS4
# Nintendo Switch

# %% [markdown]
# # Filtrando Dados

# %%
# selecionando linha pelo indice de 0 a 5
df.iloc[0:6]
# selecionando linha pelo indice de 10 a 15
df.iloc[10:16]

# selecionando as linhas de indice 1,5,10,15
df.iloc[[1,5,10,15]]

# selecionando as linhas de indice 5,1,15,10
df.iloc[[5,1,15,10]]

# selecioando linhas e colunas especificas
df.iloc[0:6, 0:6] # linha 1, coluna 4

df.iloc[[0,6], [0,6]]

# %%
# selecionando linhas e colunas com rotulos
pesquisa_de_satisfacao.loc['XboxOne']

# selecionando uma lista de linhas e colunas especificas com rotulos
pesquisa_de_satisfacao.loc[['Nintendo Switch','XboxOne'],['Bom','Ruim','pessimo']]

# selecionando todas as linhas e colunas especificas com rotulos
pesquisa_de_satisfacao.loc[:,['Bom','pessimo']]
# Out:
#                  Bom  pessimo
# XboxOne           50       30
# PS4               21       20
# Nintendo Switch  100        1

# %%
# a forma de acesso de colunas por .NOME_DA_COLUNA do funciona se
# o nome da coluna nao tiver espacos ou caracteres especiais (espacos,-, cedilha, acentos , etc)
df.ESTADO

# df.DATA INICIAL nao funciona por causa do espaco


# para colunas que possuem espacos ou caracteres especiais, devemos usar o formato de colchetes
df['DATA INICIAL']

#

df[['DATA INICIAL','ESTADO','REGIÃO']]
# Out:
#        DATA INICIAL              ESTADO        REGIÃO
# 0        2004-05-09    DISTRITO FEDERAL  CENTRO OESTE
# 1        2004-05-09               GOIAS  CENTRO OESTE
# 2        2004-05-09         MATO GROSSO  CENTRO OESTE
# 3        2004-05-09  MATO GROSSO DO SUL  CENTRO OESTE
# 4        2004-05-09             ALAGOAS      NORDESTE
# ...             ...                 ...           ...
# 120818   2021-04-25             RORAIMA         NORTE
# 120819   2021-04-25      SANTA CATARINA           SUL
# 120820   2021-04-25           SAO PAULO       SUDESTE
# 120821   2021-04-25             SERGIPE      NORDESTE
# 120822   2021-04-25           TOCANTINS         NORTE
#
# [120823 rows x 3 columns]

# %%
# # deleta/remove uma coluna in place (no proprio dataframe) a coluna de nome 'Unnamed: 0'

# df['COLUNA SEM NOCÃO'] = 'DEFAULT'
# # coluna a partir de lista
# df['# coluna a partir de lista'] = range(len(df))

# df['PRECO MEDIO DE REVENDA (DOLAR)'] = df['PREÇO MÉDIO REVENDA'] * 6

# df['Unnamed: 0'] = range(df.shape[0])

# df



# del df['Unnamed: 0']
# del df['COLUNA SEM NOCÃO']
# del df['# coluna a partir de lista']
# del df['PRECO MEDIO DE REVENDA (DOLAR)']

# df

# df.to_csv('/content/drive/MyDrive/Colab dados_limpos_de_preco_gas.csv', index=False)

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab dados_limpos_de_preco_gas.csv')
data

# mostra os valores unicos presentes na coluna de estado
data['ESTADO'].unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %%
# faz uma comparacao elemento a elemento de uma series, retornando uma series de booleans
selecao_SP = data['ESTADO'] == 'SAO PAULO'
data[selecao_SP]

dados_de_sp = data[data['ESTADO'] == 'SAO PAULO']
dados_de_sp

data.loc[data['ESTADO'] == 'SAO PAULO']

# ainda nao foi alterado pois precisamos passar o parametro inplace=true
postos_sp = data.query('ESTADO == "SAO PAULO"')
postos_sp.reset_index(drop=True)
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...           ...         ...      ...        ...               ...
# 4814   2021-04-25  2021-05-01  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4815   2021-04-25  2021-05-01  SUDESTE  SAO PAULO               GLP
# 4816   2021-04-25  2021-05-01  SUDESTE  SAO PAULO               GNV
# 4817   2021-04-25  2021-05-01  SUDESTE  SAO PAULO       OLEO DIESEL
# 4818   2021-04-25  2021-05-01  SUDESTE  SAO PAULO   OLEO DIESEL S10
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# ...

# %%
postos_sp = data.query('ESTADO == "SAO PAULO"').reset_index(drop=True)
postos_sp

# %% [markdown]
# Filtrando dados com condicoes especificas

# %%
data['ESTADO'] == 'RIO DE JANEIRO'


postos_rj = data[data['ESTADO'] == 'RIO DE JANEIRO']
postos_rj[postos_rj['PREÇO MÉDIO REVENDA'] > 2]

# sp_rj = data[((data['ESTADO'] == 'RIO DE JANEIRO') | (data['ESTADO'] == 'SAO PAULO')) & (data['PREÇO MÉDIO REVENDA'] > 2) & (sp_rj['PRODUTO'] == 'ETANOL HIDRATADO')].reset_index(drop=True)


sp_rj = data[(data['ESTADO']=='RIO DE JANEIRO') | (data['ESTADO'] == 'SAO PAULO')].reset_index(drop=True)
sp_rj

sp_rj_media_revenda_maior_2 = sp_rj[sp_rj['PREÇO MÉDIO REVENDA']> 2].reset_index(drop=True)

sp_rj_media_revenda_maior_2_por_produto = sp_rj_media_revenda_maior_2[sp_rj_media_revenda_maior_2['PRODUTO'] == 'ETANOL HIDRATADO']
sp_rj_media_revenda_maior_2_por_produto



# sp_rj[(sp_rj['PREÇO MÉDIO REVENDA']>2) & (sp_rj['PRODUTO'] == 'ETANOL HIDRATADO')]
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 0      2006-02-26  2006-03-04  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 1      2006-03-05  2006-03-11  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2      2006-03-12  2006-03-18  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 3      2006-03-19  2006-03-25  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 4      2006-03-26  2006-04-01  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...           ...         ...      ...             ...               ...
# 6852   2021-04-11  2021-04-17  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 6865   2021-04-18  2021-04-24  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 6866   2021-04-18  2021-04-24  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 6879   2021-04-25  2021-05-01  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 6880   2021-04-25  2021-05-01  SUDESTE       SAO PAULO  ETANOL HIDRATADO
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...
