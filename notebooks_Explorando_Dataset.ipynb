# %% [markdown]
# ##Explorando os Dados com Pandas

# %%
# importando a biblioteca
import pandas as pd

#  series sao dados unidimensionais (com apenas colunas ou linhas)
s = pd.Series([1,2,3,4,5])

s


# com type voce pode ver o tipo de dado que esta manuzeando
type(s)
# Out:
# pandas.core.series.Series

# %%
# com a funcao DataFrame podemos criar tabelas com linhas e colunas
pessoas = pd.DataFrame(
  {
      'nome':['Gean','Marcos'],
      'Idade':[22,40]
  }

)
pessoas
# Out:
#      nome  Idade
# 0    Gean     22
# 1  Marcos     40

# %%
# # lendo dados com read_csv
# df = pd.read_csv('insurance.csv')

# # o head serve para ver as primeiras 5 linhas e vc pode definir a qtde de linhas que quer ver
# df.head(10)
# # o tail serve para ver as ultimas 5 linhas
# df.tail()
# # descreve as colunas que temos no dataframe
# df.columns
# # conta linhas e colunas e retorna a qtde das duas
# df.shape
# # apresenta informacoes gerais de um dataframe
# df.info()

# %% [markdown]
# ##Acessando Dados

# %%
# acessando dados de uma coluna especifica
# df['age'].head()


# # puxando varias colunas de uma vez
# # para isso passamos uma lista de colunas dentro dos colchetes
# # df[['age','bmi','charges']].head()


# # com o loc nos puxamos a posicao/indice de uma linha
# # mas como o loc funciona com rotulos no segundo parametro
# # voce pode passar colunas dentro dos colchetes pra puxar as colunas tambem
# # df.loc[0:10,['age','bmi','charges']]

# df.head()

# %% [markdown]
# ## Exercicios

# %%
# from os import fchdir
# # Contando as pessoas com filhos
# contagem = 0
# for c in df['children']:
#   if c > 0:
#     contagem += 1
# print(contagem)

# # selecionando as linhas 100 a 120

# df.loc[100:120,['age','bmi','charges']]

# %% [markdown]
# ## Importando dados e transformando em CSV

# %%
import pandas as pd


# importando um arquivo tsv (Separado por tabulacao) passando o sep=\t
df = pd.read_csv('./Datas/2004-2021.tsv', sep='\t')


# df

df.head()

# df.to_csv('2004-2021.csv', index=False)

# df = pd.read_csv('./datasets/2004-2021.csv')
# df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120823 entries, 0 to 120822
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   120823 non-null  object
#  1   DATA FINAL                     120823 non-null  object
#  2   REGIÃO                         120823 non-null  object
#  3   ESTADO                         120823 non-null  object
#  4   PRODUTO                        120823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   120823 non-null  int64
#  6   UNIDADE DE MEDIDA              120823 non-null  object
#  7   PREÇO MÉDIO REVENDA            120823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          120823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           120823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           120823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           120823 non-null  object
# ...

# %% [markdown]
# ## Criando um dataframe de personagens de Star Wars

# %%
personagens_df = pd.DataFrame({
     'nome':['Luke Skywalker','Yoda','Palpatine'],
     'idade':[20,1000,70],
     'peso':[60.1,15.2,70.5],
     'é jedi?':[True,True,False]
    })
personagens_df.info()
personagens_df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   nome     3 non-null      object
#  1   idade    3 non-null      int64
#  2   peso     3 non-null      float64
#  3   é jedi?  3 non-null      bool
# dtypes: bool(1), float64(1), int64(1), object(1)
# memory usage: 135.0+ bytes
# Index(['nome', 'idade', 'peso', 'é jedi?'], dtype='object')

# %% [markdown]
# Renomeando Colunas de um DataFrame com DataFrame.rename(columns)

# %%
# Para renomear uma coluna de um df voce pode usar DataFrame.rename
# que cria uma copia com as colunas renomeadas
# temos que passar o atributo columns para renomear uma coluna
personagens_df_renomeado = personagens_df.rename(columns={
      'nome': 'Nome Completo',
      'idade': 'Idade'})
personagens_df_renomeado
# Out:
#     Nome Completo  Idade  peso  é jedi?
# 0  Luke Skywalker     20  60.1     True
# 1            Yoda   1000  15.2     True
# 2       Palpatine     70  70.5    False

# %% [markdown]
# Para renomear o DF original precisamos passar o parametro `inplace=True`

# %%
personagens_df.rename(columns={
    'nome':'Nome Completo',
    'idade':'Idade'
},inplace=True)

personagens_df
# Out:
#     Nome Completo  Idade  peso  é jedi?
# 0  Luke Skywalker     20  60.1     True
# 1            Yoda   1000  15.2     True
# 2       Palpatine     70  70.5    False

# %% [markdown]
# Tambem podemos renomear todas as colunas de um DF é utilizar o atributo `DataFrame.columns `passando uma lista com os novos nomes

# %%
personagens_df.columns = ['NOME','IDADE','PESO','É JEDI']
personagens_df
# Out:
#              NOME  IDADE  PESO  É JEDI
# 0  Luke Skywalker     20  60.1    True
# 1            Yoda   1000  15.2    True
# 2       Palpatine     70  70.5   False

# %%
# Seleciona uma coluna inteira

df['ESTADO']
# Out:
# 0           DISTRITO FEDERAL
# 1                      GOIAS
# 2                MATO GROSSO
# 3         MATO GROSSO DO SUL
# 4                    ALAGOAS
#                  ...
# 120818               RORAIMA
# 120819        SANTA CATARINA
# 120820             SAO PAULO
# 120821               SERGIPE
# 120822             TOCANTINS
# Name: ESTADO, Length: 120823, dtype: object

# %%
# Selecioando uma coluna inteira 
# esta forma de acesso, so funciona para colunas com nomes sem espacos, acentos, etc( caracteres especiais ) 

df.ESTADO
# Out:
# 0           DISTRITO FEDERAL
# 1                      GOIAS
# 2                MATO GROSSO
# 3         MATO GROSSO DO SUL
# 4                    ALAGOAS
#                  ...
# 120818               RORAIMA
# 120819        SANTA CATARINA
# 120820             SAO PAULO
# 120821               SERGIPE
# 120822             TOCANTINS
# Name: ESTADO, Length: 120823, dtype: object

# %%
type(df['ESTADO'])
# Out:
# pandas.core.series.Series

# %%
df.iloc[1]
# Out:
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# Name: 1, dtype: object

# %%
type(df.iloc[1])
# Out:
# pandas.core.series.Series

# %%
pd.Series([5.0,7.0,10.0], index=['prova 1','prova 2', 'prova 3'], name='Provas do Geanzin mil grau')
# Out:
# prova 1     5.0
# prova 2     7.0
# prova 3    10.0
# Name: Provas do Geanzin mil grau, dtype: float64

# %%
# A series retornada referente a coluna,NAO É UMA COPIA, mas sim, uma referencia/view a coluna do dataframe
produto_view = df['PRODUTO']

# %%
# agora com o metodo .copy estamos copiando a coluna produto para a variavel 'bkp_produto_view'
bkp_produto_view = df['PRODUTO'].copy()
bkp_produto_view
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 120818     OLEO DIESEL S10
# 120819     OLEO DIESEL S10
# 120820     OLEO DIESEL S10
# 120821     OLEO DIESEL S10
# 120822     OLEO DIESEL S10
# Name: PRODUTO, Length: 120823, dtype: object

# %%
# atribuindo o valor constante 'combustivel' para cada linha da variavel/coluna PRODUTO

df['PRODUTO'] = 'Combustivel'

# %%
df
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...             ...         ...           ...                 ...
# 120818   2021-04-25  2021-05-01         NORTE             RORAIMA
# 120819   2021-04-25  2021-05-01           SUL      SANTA CATARINA
# 120820   2021-04-25  2021-05-01       SUDESTE           SAO PAULO
# 120821   2021-04-25  2021-05-01      NORDESTE             SERGIPE
# 120822   2021-04-25  2021-05-01         NORTE           TOCANTINS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       Combustivel                           127              R$/l
# ...

# %%
df['PRODUTO']
# Out:
# 0         Combustivel
# 1         Combustivel
# 2         Combustivel
# 3         Combustivel
# 4         Combustivel
#              ...
# 120818    Combustivel
# 120819    Combustivel
# 120820    Combustivel
# 120821    Combustivel
# 120822    Combustivel
# Name: PRODUTO, Length: 120823, dtype: object

# %%
type(bkp_produto_view)
# Out:
# pandas.core.series.Series

# %%
df['PRODUTO'] = [f'PRODUTO {l}' for l in range(len(df['PRODUTO'])) ]

# %%
df
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...             ...         ...           ...                 ...
# 120818   2021-04-25  2021-05-01         NORTE             RORAIMA
# 120819   2021-04-25  2021-05-01           SUL      SANTA CATARINA
# 120820   2021-04-25  2021-05-01       SUDESTE           SAO PAULO
# 120821   2021-04-25  2021-05-01      NORDESTE             SERGIPE
# 120822   2021-04-25  2021-05-01         NORTE           TOCANTINS
#
#                PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0            PRODUTO 0                           127              R$/l
# ...

# %%
df['PRODUTO'] = bkp_produto_view
df
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...             ...         ...           ...                 ...
# 120818   2021-04-25  2021-05-01         NORTE             RORAIMA
# 120819   2021-04-25  2021-05-01           SUL      SANTA CATARINA
# 120820   2021-04-25  2021-05-01       SUDESTE           SAO PAULO
# 120821   2021-04-25  2021-05-01      NORDESTE             SERGIPE
# 120822   2021-04-25  2021-05-01         NORTE           TOCANTINS
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...
